# %% [markdown]
# # Strong Scaling for We
#
# **States only**
#
# Since the number of states is small, run for (2, 2, 2) k-points (fixed), with no k-distribution.
# Threads fixed at 1
# MPI processes: 1, 2, 3, 4, 5, 6, 7, 8
# Note, this might not be good enough - I should favour WSe instead, which has 40 occupied.
#
# **k-points only**
#
# No k-distribution.
# Run (4,4,4) k-points and single thread.
# Use 1 node. Increase total MPI processes as  4, 16, 32, 64
# Use 2 nodes. Increase total MPI processes as  4, 16, 32, 64
